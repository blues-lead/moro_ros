# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import DotDict
import yaml

# Load the map definition from file
filepath = '../../../moro_simulator' + '/world/maze_map.yaml'
with open(filepath) as f:
    msg = DotDict(yaml.safe_load(f))

# %%
# %matplotlib notebook

from probabilistic_roadmap import ProbabilisticRoadmap
import matplotlib.pyplot as plt

import numpy as np

# Set random seed to compare different parameters
np.random.seed(45)

prm = ProbabilisticRoadmap(msg)
prm.plot()

for node, coord in enumerate(prm.nodes):
    plt.text(coord[0], coord[1], str(node))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from shortest_path import dynamic_programming

# %%
path = dynamic_programming(prm.graph, 10, 3)
path
# Out:
# array([10, 55, 33, 19, 59,  7,  3])

# %%
plt.figure()
prm.plot(path)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-02d1dc1e0dd5> in <module>
#       1 plt.figure()
# ----> 2 prm.plot(path)
#       3 plt.show()
#
# ~/catkin_ws/src/moro_ros/moro_navigation/src/moro_navigation/probabilistic_roadmap.py in plot(self, path)
#     226         ax.set_ylim((self._ymin, self._ymax))
#     227 #
# --> 228         if path:
#     229             path = self.nodes[path]
#     230             ax.plot(path[:, 0], path[:, 1], 'ro-', linewidth=2)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
